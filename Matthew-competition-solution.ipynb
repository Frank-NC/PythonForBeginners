# %%
code = "Bnlcdvbnbyaj, Xyydpwx, Ngynlcx Yjcaxwdv, Armmrtdudb, Fqrlq Qjaah Yxccna bynuu fruu Cajwboxav wjbch Kxppjacb oaxv bxvncqrwp bljah rwcx bxvncqrwp bruuh?"
decode = ""
i = 0

for x in range(0, 26):
    i = i + 1
    
    for character in code:  
        if character.isalpha():
            if character.isupper():
                if ord(character) + i > 90:
                    decode += chr( ord(character) + i - 26)
                else:
                    decode += chr(ord(character) + i)
            else:
                if ord(character) + i > 122:
                    decode += chr( ord(character) + i - 26)
                else:
                    decode += chr(ord(character) + i)
        else:
            decode += character
     
    print(decode)
    print("i = " + str(i))
    print('')
    decode = ''
# Out:
# Comdewcoczbk, Yzzeqxy, Ohzomdy Zkdbyxew, Bsnnsuevec, Grsmr Rkbbi Zyddob czovv gsvv Dbkxcpybw xkcdi Lyqqkbdc pbyw cywodrsxq cmkbi sxdy cywodrsxq csvvi?
# i = 1
#
# Dpnefxdpdacl, Zaafryz, Piapnez Aleczyfx, Ctootvfwfd, Hstns Slccj Azeepc dapww htww Eclydqzcx yldej Mzrrlced qczx dzxpestyr dnlcj tyez dzxpestyr dtwwj?
# i = 2
#
# Eqofgyeqebdm, Abbgsza, Qjbqofa Bmfdazgy, Duppuwgxge, Ituot Tmddk Baffqd ebqxx iuxx Fdmzerady zmefk Nassmdfe rday eayqftuzs eomdk uzfa eayqftuzs euxxk?
# i = 3
#
# Frpghzfrfcen, Bcchtab, Rkcrpgb Cngebahz, Evqqvxhyhf, Juvpu Uneel Cbggre fcryy jvyy Genafsbez anfgl Obttnegf sebz fbzrguvat fpnel vagb fbzrguvat fvyyl?
# i = 4
#
# Gsqhiagsgdfo, Cddiubc, Sldsqhc Dohfcbia, Fwrrwyizig, Kvwqv Voffm Dchhsf gdszz kwzz Hfobgtcfa boghm Pcuuofhg tfca gcashvwbu gqofm wbhc gcashvwbu gwzzm?
# i = 5
#
# Htrijbhthegp, Deejvcd, Tmetrid Epigdcjb, Gxssxzjajh, Lwxrw Wpggn Ediitg hetaa lxaa Igpchudgb cphin Qdvvpgih ugdb hdbtiwxcv hrpgn xcid hdbtiwxcv hxaan?
# i = 6
#
# ...

# %%
message=str(input("Please input the message which will be shifted right."))
list1 =list(message)
list2=[]
shift = 0
while True:
    shift= shift +1
    for x in list1:
        y = x
        if x.isalpha() == True:
            if x.islower() == True:
                asciiInt = ord(x)
                asciiInt = asciiInt + shift
                if asciiInt >= 123:
                    reverter = asciiInt-123
                    asciiInt = 97 + reverter
            if x.isupper() == True:
                    asciiInt = ord(x)
                    asciiInt = asciiInt + shift
                    if asciiInt >= 91:
                            reverter = asciiInt-91
                            asciiInt = 65 + reverter
            y=chr(asciiInt)
        list2.append(y)
    print(shift,''.join(list2))
    list2=[]
    if shift == 26:
        break
# Out:
# Please input the message which will be shifted right.Bnlcdvbnbyaj, Xyydpwx, Ngynlcx Yjcaxwdv, Armmrtdudb, Fqrlq Qjaah Yxccna bynuu fruu Cajwboxav wjbch Kxppjacb oaxv bxvncqrwp bljah rwcx bxvncqrwp bruuh?
# 1 Comdewcoczbk, Yzzeqxy, Ohzomdy Zkdbyxew, Bsnnsuevec, Grsmr Rkbbi Zyddob czovv gsvv Dbkxcpybw xkcdi Lyqqkbdc pbyw cywodrsxq cmkbi sxdy cywodrsxq csvvi?
# 2 Dpnefxdpdacl, Zaafryz, Piapnez Aleczyfx, Ctootvfwfd, Hstns Slccj Azeepc dapww htww Eclydqzcx yldej Mzrrlced qczx dzxpestyr dnlcj tyez dzxpestyr dtwwj?
# 3 Eqofgyeqebdm, Abbgsza, Qjbqofa Bmfdazgy, Duppuwgxge, Ituot Tmddk Baffqd ebqxx iuxx Fdmzerady zmefk Nassmdfe rday eayqftuzs eomdk uzfa eayqftuzs euxxk?
# 4 Frpghzfrfcen, Bcchtab, Rkcrpgb Cngebahz, Evqqvxhyhf, Juvpu Uneel Cbggre fcryy jvyy Genafsbez anfgl Obttnegf sebz fbzrguvat fpnel vagb fbzrguvat fvyyl?
# 5 Gsqhiagsgdfo, Cddiubc, Sldsqhc Dohfcbia, Fwrrwyizig, Kvwqv Voffm Dchhsf gdszz kwzz Hfobgtcfa boghm Pcuuofhg tfca gcashvwbu gqofm wbhc gcashvwbu gwzzm?
# ...
